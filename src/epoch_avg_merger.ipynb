# %%
import os
import numpy as np
import struct


def avg_to_ascii(file_name, chanlist='all', typerange='all', accepttype='all', rtrange='all', responsetype='all', data_format='auto'):
    """This function reads the data from a binary EEG file, extracts and scales the data, and returns it in ASCII format.

    Parameters:

    - **file_name (str)**: The name of the binary EEG file you want to read.
    - **chanlist (str or list)**: List of channels to read from the file. Default is 'all', which reads all channels in the file.
    - **triallist (str or list)**: List of trials to read from the file. Default is 'all', which reads all trials in the file.
    - **typerange (str, list or tuple)**: Range of type codes to read from the file. Default is 'all', which reads all type codes in the file.
    - **accepttype (str, list or tuple)**: Range of accept codes to read from the file. Default is 'all', which reads all accept codes in the file.
    - **rtrange (str, list or tuple)**: Range of reaction times to read from the file. Default is 'all', which reads all reaction times in the file.
    - **responsetype (str, list, or tuple)**: Range of response codes to read from the file. Default is 'all', which reads all response codes in the file.
    - **data_format (str)**: The format in which to return the data. Default is 'auto', which returns the data in its native format.

    Returns:

    - **data (numpy.ndarray)**: A 2D array containing the EEG data (in volts) for each channel and time point.
    - **chan_names (list of str)**: A list of channel names.
    - **rate (int)**: The sample rate (in Hz) of the EEG data.
    - **xmin (float)**: The minimum time (in seconds) of the data."""

    # Check if file ends with .eeg
    if not file_name.endswith('.avg'):
        raise ValueError("File must be a binary avg file (.avg).")

    if not os.path.isfile(file_name):
        raise ValueError(f"File {file_name} not found.")

    with open(file_name, 'rb') as f:
        try:
            # Read general part of the ERP header and set variables
            f.read(20)  # skip revision number
            f.read(342)  # skip the first 362 bytes

            nsweeps = struct.unpack('<H', f.read(2))[0]  # number of sweeps
            accepted_sweeps = struct.unpack('<H', f.read(2))[
                0]  # number of accepted sweeps
            # If accepted_sweeps is 0, raise an error 
            if accepted_sweeps == 0:
                raise ValueError(
                    "No accepted sweeps found.")
            rejected_sweeps = struct.unpack('<H', f.read(2))[
                0]  # number of rejected sweepss
            # number of points per waveform
            pnts = struct.unpack('<H', f.read(2))[0]
            chan = struct.unpack('<H', f.read(2))[0]  # number of channels
            f.read(4)  # skip 4 bytes
            rate = struct.unpack('<H', f.read(2))[0]  # sample rate (Hz)
            f.read(127)  # skip 127 bytes
            xmin = struct.unpack('<f', f.read(4))[0]  # in s
            xmax = struct.unpack('<f', f.read(4))[0]  # in s
            f.read(387)  # skip 387 bytes

            print(f"Number of sweeps: {nsweeps}")

            # Read electrode configuration
            chan_names = []
            baselines = []
            sensitivities = []
            calibs = []
            for elec in range(chan):
                chan_name = f.read(10).decode('ascii').strip('\x00')
                chan_names.append(chan_name)
                f.read(37)  # skip 37 bytes
                baseline = struct.unpack('<H', f.read(2))[0]
                baselines.append(baseline)
                f.read(10)  # skip 10 bytes
                sensitivity = struct.unpack('<f', f.read(4))[0]
                sensitivities.append(sensitivity)
                f.read(8)  # skip 8 bytes
                calib = struct.unpack('<f', f.read(4))[0]
                calibs.append(calib)

        except struct.error:
            raise ValueError(
                "Error reading binary file. File may be corrupted or not in the expected format.")
        except Exception as e:
            raise ValueError(f"Error reading {file_name}: {e}")

    # Read and process epoch datapoints data
    data = np.empty((len(chan_names), pnts), dtype=float)

    with open(file_name, 'rb') as f:
        # Ensure the file pointer is at the beginning of the EEG data
        f.seek((900 + chan * 75))

        for chan in range(len(chan_names)):
            f.read(5)  # skip 5 bytes
            for point in range(pnts):
                data[chan, point] = struct.unpack('<f', f.read(4))[
                    0] * calibs[chan] / accepted_sweeps

    # Convert data from microvolts to volts
    data = data * 1e-6
    # Return relevant data in ASCII format
    return data, chan_names, rate, xmin

# %%
import pandas as pd
import numpy as np
import os
import mne
#Get current data directory
data_path = '/home/woess/workspace/mnt/c/Users/woess/Desktop/ANT_coga_avg/avg'
#Change to data directory
os.chdir(data_path)
i = 0
df_list = []

for i, filename in enumerate(os.listdir(data_path)):
    
    file = os.path.join(filename)
    if file.endswith('.avg'):
        print(filename + " " + str(i) + "/" + str(len(os.listdir(data_path))))
        try:
            data, chan_names, rate, xmin = avg_to_ascii(file)
        except ValueError as e:
            print(e)
            continue
        # Convert data from volts to microvolts
        data = data * 1e6
        first = int(round(xmin * rate))
        last = first + np.shape(data)[-1] - 1
        
        time = np.arange(first, last + 1, dtype=np.float64) / rate
        # df["subject"] = filename[:-4]
        # df["time_ms"] = time.tolist()
        # df = pd.melt(df,var_name='Channel', id_vars = ["time_ms","subject"]) #Convert Wide to Long 
        num_t_points = len(data[1])
        # Convert data array into long format
        data = data.flatten()
        time = np.tile(time, len(chan_names))
        chan_names = np.repeat(chan_names, num_t_points)
        df = pd.DataFrame({'subject': filename, 'time_ms': time, 'value': data, 'channel': chan_names})
        df_list.append(df)

        
subject_df = pd.concat(df_list, ignore_index=True)
# Out:
# 50001003_ANT_Ac.avg 0/1050
# Number of sweeps: 300
# 50001003_ANT_Jc.avg 1/1050
# Number of sweeps: 300
# 50001003_ANT_Pc.avg 2/1050
# Number of sweeps: 300
# 50001003_ANT_Wc.avg 3/1050
# Number of sweeps: 300
# 50001066_ANT_Ac.avg 4/1050
# Number of sweeps: 300
# 50001066_ANT_Jc.avg 5/1050
# Number of sweeps: 300
# 50001066_ANT_Pc.avg 6/1050
# Number of sweeps: 300
# 50001066_ANT_Wc.avg 7/1050
# Number of sweeps: 300
# 50004003_ANT_Ac.avg 8/1050
# Number of sweeps: 300
# 50004003_ANT_Jc.avg 9/1050
# Number of sweeps: 300
# 50004003_ANT_Pc.avg 10/1050
# Number of sweeps: 300
# 50004003_ANT_Wc.avg 11/1050
# Number of sweeps: 300
# 50004023_ANT_Ac.avg 12/1050
# Number of sweeps: 300
# 50004023_ANT_Jc.avg 13/1050
# Number of sweeps: 300
# 50004023_ANT_Pc.avg 14/1050
# Number of sweeps: 300
# 50004023_ANT_Wc.avg 15/1050
# Number of sweeps: 300
# 50007016_ANT_Ac.avg 16/1050
# Number of sweeps: 300
# 50007016_ANT_Jc.avg 17/1050
# Number of sweeps: 300
# 50007016_ANT_Pc.avg 18/1050
# Number of sweeps: 300
# 50007016_ANT_Wc.avg 19/1050
# Number of sweeps: 300
# 50009011_ANT_Ac.avg 20/1050
# Number of sweeps: 300
# 50009011_ANT_Jc.avg 21/1050
# Number of sweeps: 300
# 50009011_ANT_Pc.avg 22/1050
# Number of sweeps: 300
# 50009011_ANT_Wc.avg 23/1050
# Number of sweeps: 300
# 50015002_ANT_Ac.avg 24/1050
# Number of sweeps: 300
# 50015002_ANT_Jc.avg 25/1050
# Number of sweeps: 300
# 50015002_ANT_Pc.avg 26/1050
# Number of sweeps: 300
# 50015002_ANT_Wc.avg 27/1050
# Number of sweeps: 300
# 50015015_ANT_Ac.avg 28/1050
# Number of sweeps: 300
# 50015015_ANT_Jc.avg 29/1050
# Number of sweeps: 300
# 50015015_ANT_Pc.avg 30/1050
# Number of sweeps: 300
# 50015015_ANT_Wc.avg 31/1050
# Number of sweeps: 300
# 50017009_ANT_Ac.avg 32/1050
# Number of sweeps: 300
# 50017009_ANT_Jc.avg 33/1050
# Number of sweeps: 300
# 50017009_ANT_Pc.avg 34/1050
# Number of sweeps: 300
# 50017009_ANT_Wc.avg 35/1050
# Number of sweeps: 300
# 50018003_ANT_Ac.avg 36/1050
# Number of sweeps: 300
# 50018003_ANT_Jc.avg 37/1050
# Number of sweeps: 300
# 50018003_ANT_Pc.avg 38/1050
# Number of sweeps: 300
# 50018003_ANT_Wc.avg 39/1050
# Number of sweeps: 300
# 50018004_ANT_Ac.avg 40/1050
# Number of sweeps: 300
# 50018004_ANT_Jc.avg 41/1050
# Number of sweeps: 300
# 50018004_ANT_Pc.avg 42/1050
# Number of sweeps: 300
# 50018004_ANT_Wc.avg 43/1050
# Number of sweeps: 300
# 50018006_ANT_Ac.avg 44/1050
# Number of sweeps: 300
# 50018006_ANT_Jc.avg 45/1050
# Number of sweeps: 300
# 50018006_ANT_Pc.avg 46/1050
# Number of sweeps: 300
# 50018006_ANT_Wc.avg 47/1050
# Number of sweeps: 300
# 50018010_ANT_Ac.avg 48/1050
# Number of sweeps: 300
# 50018010_ANT_Jc.avg 49/1050
# Number of sweeps: 300
# 50018010_ANT_Pc.avg 50/1050
# Number of sweeps: 300
# 50018010_ANT_Wc.avg 51/1050
# Number of sweeps: 300
# 50018011_ANT_Ac.avg 52/1050
# Number of sweeps: 300
# 50018011_ANT_Jc.avg 53/1050
# Number of sweeps: 300
# 50018011_ANT_Pc.avg 54/1050
# Number of sweeps: 300
# 50018011_ANT_Wc.avg 55/1050
# Number of sweeps: 300
# 50018013_ANT_Ac.avg 56/1050
# Number of sweeps: 300
# 50018013_ANT_Jc.avg 57/1050
# Number of sweeps: 300
# 50018013_ANT_Pc.avg 58/1050
# Number of sweeps: 300
# 50018013_ANT_Wc.avg 59/1050
# Number of sweeps: 300
# 50018014_ANT_Ac.avg 60/1050
# Number of sweeps: 300
# 50018014_ANT_Jc.avg 61/1050
# Number of sweeps: 300
# 50018014_ANT_Pc.avg 62/1050
# Number of sweeps: 300
# 50018014_ANT_Wc.avg 63/1050
# Number of sweeps: 300
# 50018021_ANT_Ac.avg 64/1050
# Number of sweeps: 300
# 50018021_ANT_Jc.avg 65/1050
# Number of sweeps: 300
# 50018021_ANT_Pc.avg 66/1050
# Number of sweeps: 300
# 50018021_ANT_Wc.avg 67/1050
# Number of sweeps: 300
# 50018046_ANT_Ac.avg 68/1050
# Number of sweeps: 300
# 50018046_ANT_Jc.avg 69/1050
# Number of sweeps: 300
# 50018046_ANT_Pc.avg 70/1050
# Number of sweeps: 300
# 50018046_ANT_Wc.avg 71/1050
# Number of sweeps: 300
# 50018050_ANT_Ac.avg 72/1050
# Number of sweeps: 300
# 50018050_ANT_Jc.avg 73/1050
# Number of sweeps: 300
# 50018050_ANT_Pc.avg 74/1050
# Number of sweeps: 300
# 50018050_ANT_Wc.avg 75/1050
# Number of sweeps: 300
# 50018060_ANT_Ac.avg 76/1050
# Number of sweeps: 300
# 50018060_ANT_Jc.avg 77/1050
# Number of sweeps: 300
# 50018060_ANT_Pc.avg 78/1050
# Number of sweeps: 300
# 50018060_ANT_Wc.avg 79/1050
# Number of sweeps: 300
# 50018169_ANT_Ac.avg 80/1050
# Number of sweeps: 300
# 50018169_ANT_Jc.avg 81/1050
# Number of sweeps: 300
# 50018169_ANT_Pc.avg 82/1050
# Number of sweeps: 300
# 50018169_ANT_Wc.avg 83/1050
# Number of sweeps: 300
# 50018178_ANT_Ac.avg 84/1050
# Number of sweeps: 300
# 50018178_ANT_Jc.avg 85/1050
# Number of sweeps: 300
# 50018178_ANT_Pc.avg 86/1050
# Number of sweeps: 300
# 50018178_ANT_Wc.avg 87/1050
# Number of sweeps: 300
# 50018185_ANT_Ac.avg 88/1050
# Number of sweeps: 300
# 50018185_ANT_Jc.avg 89/1050
# Number of sweeps: 300
# 50018185_ANT_Pc.avg 90/1050
# Number of sweeps: 300
# 50018185_ANT_Wc.avg 91/1050
# Number of sweeps: 300
# 50019058_ANT_Ac.avg 92/1050
# Number of sweeps: 300
# 50019058_ANT_Jc.avg 93/1050
# Number of sweeps: 300
# 50019058_ANT_Pc.avg 94/1050
# Number of sweeps: 300
# 50019058_ANT_Wc.avg 95/1050
# Number of sweeps: 300
# 50022005_ANT_Ac.avg 96/1050
# Number of sweeps: 300
# 50022005_ANT_Jc.avg 97/1050
# Number of sweeps: 300
# 50022005_ANT_Pc.avg 98/1050
# Number of sweeps: 300
# 50022005_ANT_Wc.avg 99/1050
# Number of sweeps: 300
# 50023005_ANT_Ac.avg 100/1050
# Number of sweeps: 300
# 50023005_ANT_Jc.avg 101/1050
# Number of sweeps: 300
# 50023005_ANT_Pc.avg 102/1050
# Number of sweeps: 300
# 50023005_ANT_Wc.avg 103/1050
# Number of sweeps: 300
# 50029002_ANT_Ac.avg 104/1050
# Number of sweeps: 300
# 50029002_ANT_Jc.avg 105/1050
# Number of sweeps: 300
# 50029002_ANT_Pc.avg 106/1050
# Number of sweeps: 300
# 50029002_ANT_Wc.avg 107/1050
# Number of sweeps: 300
# 50031002_ANT_Ac.avg 108/1050
# Number of sweeps: 300
# 50031002_ANT_Jc.avg 109/1050
# Number of sweeps: 300
# 50031002_ANT_Pc.avg 110/1050
# Number of sweeps: 300
# 50031002_ANT_Wc.avg 111/1050
# Number of sweeps: 300
# 50035016_ANT_Ac.avg 112/1050
# Number of sweeps: 300
# 50035016_ANT_Jc.avg 113/1050
# Number of sweeps: 300
# 50035016_ANT_Pc.avg 114/1050
# Number of sweeps: 300
# 50035016_ANT_Wc.avg 115/1050
# Number of sweeps: 300
# 50035017_ANT_Ac.avg 116/1050
# Number of sweeps: 300
# 50035017_ANT_Jc.avg 117/1050
# Number of sweeps: 300
# 50035017_ANT_Pc.avg 118/1050
# Number of sweeps: 300
# 50035017_ANT_Wc.avg 119/1050
# Number of sweeps: 300
# 50036015_ANT_Ac.avg 120/1050
# Number of sweeps: 300
# 50036015_ANT_Jc.avg 121/1050
# Number of sweeps: 300
# 50036015_ANT_Pc.avg 122/1050
# Number of sweeps: 300
# 50036015_ANT_Wc.avg 123/1050
# Number of sweeps: 300
# 50036028_ANT_Ac.avg 124/1050
# Number of sweeps: 300
# 50036028_ANT_Jc.avg 125/1050
# Number of sweeps: 300
# 50036028_ANT_Pc.avg 126/1050
# Number of sweeps: 300
# 50036028_ANT_Wc.avg 127/1050
# Number of sweeps: 300
# 50036030_ANT_Ac.avg 128/1050
# Number of sweeps: 300
# 50036030_ANT_Jc.avg 129/1050
# Number of sweeps: 300
# 50036030_ANT_Pc.avg 130/1050
# Number of sweeps: 300
# 50036030_ANT_Wc.avg 131/1050
# Number of sweeps: 300
# 50040002_ANT_Ac.avg 132/1050
# Number of sweeps: 300
# 50040002_ANT_Jc.avg 133/1050
# Number of sweeps: 300
# 50040002_ANT_Pc.avg 134/1050
# Number of sweeps: 300
# 50040002_ANT_Wc.avg 135/1050
# Number of sweeps: 300
# 50043003_ANT_Ac.avg 136/1050
# Number of sweeps: 300
# 50043003_ANT_Jc.avg 137/1050
# Number of sweeps: 300
# 50043003_ANT_Pc.avg 138/1050
# Number of sweeps: 300
# 50043003_ANT_Wc.avg 139/1050
# Number of sweeps: 300
# 50045008_ANT_Ac.avg 140/1050
# Number of sweeps: 300
# 50045008_ANT_Jc.avg 141/1050
# Number of sweeps: 300
# 50045008_ANT_Pc.avg 142/1050
# Number of sweeps: 300
# 50045008_ANT_Wc.avg 143/1050
# Number of sweeps: 300
# 50045016_ANT_Ac.avg 144/1050
# Number of sweeps: 300
# 50045016_ANT_Jc.avg 145/1050
# Number of sweeps: 300
# 50045016_ANT_Pc.avg 146/1050
# Number of sweeps: 300
# 50045016_ANT_Wc.avg 147/1050
# Number of sweeps: 300
# 50047006_ANT_Ac.avg 148/1050
# Number of sweeps: 300
# 50047006_ANT_Jc.avg 149/1050
# Number of sweeps: 300
# 50047006_ANT_Pc.avg 150/1050
# Number of sweeps: 300
# 50047006_ANT_Wc.avg 151/1050
# Number of sweeps: 300
# 50047007_ANT_Ac.avg 152/1050
# Number of sweeps: 300
# 50047007_ANT_Jc.avg 153/1050
# Number of sweeps: 300
# 50047007_ANT_Pc.avg 154/1050
# Number of sweeps: 300
# 50047007_ANT_Wc.avg 155/1050
# Number of sweeps: 300
# 50049010_ANT_Ac.avg 156/1050
# Number of sweeps: 300
# 50049010_ANT_Jc.avg 157/1050
# Number of sweeps: 300
# 50049010_ANT_Pc.avg 158/1050
# Number of sweeps: 300
# 50049010_ANT_Wc.avg 159/1050
# Number of sweeps: 300
# 50049085_ANT_Ac.avg 160/1050
# Number of sweeps: 300
# 50049085_ANT_Jc.avg 161/1050
# Number of sweeps: 300
# 50049085_ANT_Pc.avg 162/1050
# Number of sweeps: 300
# 50049085_ANT_Wc.avg 163/1050
# Number of sweeps: 300
# 50049099_ANT_Ac.avg 164/1050
# Number of sweeps: 300
# 50049099_ANT_Jc.avg 165/1050
# Number of sweeps: 300
# 50049099_ANT_Pc.avg 166/1050
# Number of sweeps: 300
# 50049099_ANT_Wc.avg 167/1050
# Number of sweeps: 300
# 50051001_ANT_Ac.avg 168/1050
# Number of sweeps: 300
# 50051001_ANT_Jc.avg 169/1050
# Number of sweeps: 300
# 50051001_ANT_Pc.avg 170/1050
# Number of sweeps: 300
# 50051001_ANT_Wc.avg 171/1050
# Number of sweeps: 300
# 50052005_ANT_Ac.avg 172/1050
# Number of sweeps: 300
# 50052005_ANT_Jc.avg 173/1050
# Number of sweeps: 300
# 50052005_ANT_Pc.avg 174/1050
# Number of sweeps: 300
# 50052005_ANT_Wc.avg 175/1050
# Number of sweeps: 300
# 50057008_ANT_Ac.avg 176/1050
# Number of sweeps: 300
# 50057008_ANT_Jc.avg 177/1050
# Number of sweeps: 300
# 50057008_ANT_Pc.avg 178/1050
# Number of sweeps: 300
# 50057008_ANT_Wc.avg 179/1050
# Number of sweeps: 300
# 50057010_ANT_Ac.avg 180/1050
# Number of sweeps: 300
# 50057010_ANT_Jc.avg 181/1050
# Number of sweeps: 300
# 50057010_ANT_Pc.avg 182/1050
# Number of sweeps: 300
# 50057010_ANT_Wc.avg 183/1050
# Number of sweeps: 300
# 50057011_ANT_Ac.avg 184/1050
# Number of sweeps: 300
# 50057011_ANT_Jc.avg 185/1050
# Number of sweeps: 300
# 50057011_ANT_Pc.avg 186/1050
# Number of sweeps: 300
# 50057011_ANT_Wc.avg 187/1050
# Number of sweeps: 300
# 50057015_ANT_Ac.avg 188/1050
# Number of sweeps: 300
# 50057015_ANT_Jc.avg 189/1050
# Number of sweeps: 300
# 50057015_ANT_Pc.avg 190/1050
# Number of sweeps: 300
# 50057015_ANT_Wc.avg 191/1050
# Number of sweeps: 300
# 50057016_ANT_Ac.avg 192/1050
# Number of sweeps: 300
# 50057016_ANT_Jc.avg 193/1050
# Number of sweeps: 300
# 50057016_ANT_Pc.avg 194/1050
# Number of sweeps: 300
# 50057016_ANT_Wc.avg 195/1050
# Number of sweeps: 300
# 50062002_ANT_Ac.avg 196/1050
# Number of sweeps: 300
# 50062002_ANT_Jc.avg 197/1050
# Number of sweeps: 300
# 50062002_ANT_Pc.avg 198/1050
# Number of sweeps: 300
# 50062002_ANT_Wc.avg 199/1050
# Number of sweeps: 300
# 50062019_ANT_Ac.avg 200/1050
# Number of sweeps: 300
# 50062019_ANT_Jc.avg 201/1050
# Number of sweeps: 300
# 50062019_ANT_Pc.avg 202/1050
# Number of sweeps: 300
# 50062019_ANT_Wc.avg 203/1050
# Number of sweeps: 300
# 50070057_ANT_Ac.avg 204/1050
# Number of sweeps: 300
# 50070057_ANT_Jc.avg 205/1050
# Number of sweeps: 300
# 50070057_ANT_Pc.avg 206/1050
# Number of sweeps: 300
# 50070057_ANT_Wc.avg 207/1050
# Number of sweeps: 300
# 50076010_ANT_Ac.avg 208/1050
# Number of sweeps: 300
# 50076010_ANT_Jc.avg 209/1050
# Number of sweeps: 300
# 50076010_ANT_Pc.avg 210/1050
# Number of sweeps: 300
# 50076010_ANT_Wc.avg 211/1050
# Number of sweeps: 300
# 50076011_ANT_Ac.avg 212/1050
# Number of sweeps: 300
# 50076011_ANT_Jc.avg 213/1050
# Number of sweeps: 300
# 50076011_ANT_Pc.avg 214/1050
# Number of sweeps: 300
# 50076011_ANT_Wc.avg 215/1050
# Number of sweeps: 300
# 50076016_ANT_Ac.avg 216/1050
# Number of sweeps: 300
# 50076016_ANT_Jc.avg 217/1050
# Number of sweeps: 300
# 50076016_ANT_Pc.avg 218/1050
# Number of sweeps: 300
# 50076016_ANT_Wc.avg 219/1050
# Number of sweeps: 300
# 50079001_ANT_Ac.avg 220/1050
# Number of sweeps: 300
# 50079001_ANT_Jc.avg 221/1050
# Number of sweeps: 300
# 50079001_ANT_Pc.avg 222/1050
# Number of sweeps: 300
# 50079001_ANT_Wc.avg 223/1050
# Number of sweeps: 300
# 50079002_ANT_Ac.avg 224/1050
# Number of sweeps: 300
# 50079002_ANT_Jc.avg 225/1050
# Number of sweeps: 300
# 50079002_ANT_Pc.avg 226/1050
# Number of sweeps: 300
# 50079002_ANT_Wc.avg 227/1050
# Number of sweeps: 300
# 50082006_ANT_Ac.avg 228/1050
# Number of sweeps: 300
# 50082006_ANT_Jc.avg 229/1050
# Number of sweeps: 300
# 50082006_ANT_Pc.avg 230/1050
# Number of sweeps: 300
# 50082006_ANT_Wc.avg 231/1050
# Number of sweeps: 300
# 50085001_ANT_Ac.avg 232/1050
# Number of sweeps: 300
# 50085001_ANT_Jc.avg 233/1050
# Number of sweeps: 300
# 50085001_ANT_Pc.avg 234/1050
# Number of sweeps: 300
# 50085001_ANT_Wc.avg 235/1050
# Number of sweeps: 300
# 50086002_ANT_Ac.avg 236/1050
# Number of sweeps: 300
# 50086002_ANT_Jc.avg 237/1050
# Number of sweeps: 300
# 50086002_ANT_Pc.avg 238/1050
# Number of sweeps: 300
# 50086002_ANT_Wc.avg 239/1050
# Number of sweeps: 300
# 50087003_ANT_Ac.avg 240/1050
# Number of sweeps: 300
# 50087003_ANT_Jc.avg 241/1050
# Number of sweeps: 300
# 50087003_ANT_Pc.avg 242/1050
# Number of sweeps: 300
# 50087003_ANT_Wc.avg 243/1050
# Number of sweeps: 300
# 50088016_ANT_Ac.avg 244/1050
# Number of sweeps: 300
# 50088016_ANT_Jc.avg 245/1050
# Number of sweeps: 300
# 50088016_ANT_Pc.avg 246/1050
# Number of sweeps: 300
# 50088016_ANT_Wc.avg 247/1050
# Number of sweeps: 300
# 50090002_ANT_Ac.avg 248/1050
# Number of sweeps: 300
# 50090002_ANT_Jc.avg 249/1050
# Number of sweeps: 300
# 50090002_ANT_Pc.avg 250/1050
# Number of sweeps: 300
# 50090002_ANT_Wc.avg 251/1050
# Number of sweeps: 300
# 50092001_ANT_Ac.avg 252/1050
# Number of sweeps: 300
# 50092001_ANT_Jc.avg 253/1050
# Number of sweeps: 300
# 50092001_ANT_Pc.avg 254/1050
# Number of sweeps: 300
# 50092001_ANT_Wc.avg 255/1050
# Number of sweeps: 300
# 50092002_ANT_Ac.avg 256/1050
# Number of sweeps: 300
# 50092002_ANT_Jc.avg 257/1050
# Number of sweeps: 300
# 50092002_ANT_Pc.avg 258/1050
# Number of sweeps: 300
# 50092002_ANT_Wc.avg 259/1050
# Number of sweeps: 300
# 50094001_ANT_Ac.avg 260/1050
# Number of sweeps: 300
# 50094001_ANT_Jc.avg 261/1050
# Number of sweeps: 300
# 50094001_ANT_Pc.avg 262/1050
# Number of sweeps: 300
# 50094001_ANT_Wc.avg 263/1050
# Number of sweeps: 300
# 50102002_ANT_Ac.avg 264/1050
# Number of sweeps: 300
# 50102002_ANT_Jc.avg 265/1050
# Number of sweeps: 300
# 50102002_ANT_Pc.avg 266/1050
# Number of sweeps: 300
# 50102002_ANT_Wc.avg 267/1050
# Number of sweeps: 300
# 50107007_ANT_Ac.avg 268/1050
# Number of sweeps: 300
# 50107007_ANT_Jc.avg 269/1050
# Number of sweeps: 300
# 50107007_ANT_Pc.avg 270/1050
# Number of sweeps: 300
# 50107007_ANT_Wc.avg 271/1050
# Number of sweeps: 300
# 50107009_ANT_Ac.avg 272/1050
# Number of sweeps: 299
# 50107009_ANT_Jc.avg 273/1050
# Number of sweeps: 299
# 50107009_ANT_Pc.avg 274/1050
# Number of sweeps: 299
# 50107009_ANT_Wc.avg 275/1050
# Number of sweeps: 299
# 50108006_ANT_Ac.avg 276/1050
# Number of sweeps: 300
# 50108006_ANT_Jc.avg 277/1050
# Number of sweeps: 300
# 50108006_ANT_Pc.avg 278/1050
# Number of sweeps: 300
# 50108006_ANT_Wc.avg 279/1050
# Number of sweeps: 300
# 50110009_ANT_Ac.avg 280/1050
# Number of sweeps: 300
# 50110009_ANT_Jc.avg 281/1050
# Number of sweeps: 300
# 50110009_ANT_Pc.avg 282/1050
# Number of sweeps: 300
# 50110009_ANT_Wc.avg 283/1050
# Number of sweeps: 300
# 50110014_ANT_Ac.avg 284/1050
# Number of sweeps: 300
# 50110014_ANT_Jc.avg 285/1050
# Number of sweeps: 300
# 50110014_ANT_Pc.avg 286/1050
# Number of sweeps: 300
# 50110014_ANT_Wc.avg 287/1050
# Number of sweeps: 300
# 50111010_ANT_Ac.avg 288/1050
# Number of sweeps: 300
# 50111010_ANT_Jc.avg 289/1050
# Number of sweeps: 300
# 50111010_ANT_Pc.avg 290/1050
# Number of sweeps: 300
# 50111010_ANT_Wc.avg 291/1050
# Number of sweeps: 300
# 50112027_ANT_Ac.avg 292/1050
# Number of sweeps: 300
# 50112027_ANT_Jc.avg 293/1050
# Number of sweeps: 300
# 50112027_ANT_Pc.avg 294/1050
# Number of sweeps: 300
# 50112027_ANT_Wc.avg 295/1050
# Number of sweeps: 300
# 50116007_ANT_Ac.avg 296/1050
# Number of sweeps: 300
# 50116007_ANT_Jc.avg 297/1050
# Number of sweeps: 300
# 50116007_ANT_Pc.avg 298/1050
# Number of sweeps: 300
# 50116007_ANT_Wc.avg 299/1050
# Number of sweeps: 300
# 50116013_ANT_Ac.avg 300/1050
# Number of sweeps: 300
# 50116013_ANT_Jc.avg 301/1050
# Number of sweeps: 300
# 50116013_ANT_Pc.avg 302/1050
# Number of sweeps: 300
# 50116013_ANT_Wc.avg 303/1050
# Number of sweeps: 300
# 50117001_ANT_Ac.avg 304/1050
# Number of sweeps: 300
# 50117001_ANT_Jc.avg 305/1050
# Number of sweeps: 300
# 50117001_ANT_Pc.avg 306/1050
# Number of sweeps: 300
# 50117001_ANT_Wc.avg 307/1050
# Number of sweeps: 300
# 50118012_ANT_Ac.avg 308/1050
# Number of sweeps: 300
# 50118012_ANT_Jc.avg 309/1050
# Number of sweeps: 300
# 50118012_ANT_Pc.avg 310/1050
# Number of sweeps: 300
# 50118012_ANT_Wc.avg 311/1050
# Number of sweeps: 300
# 50119001_ANT_Ac.avg 312/1050
# Number of sweeps: 300
# 50119001_ANT_Jc.avg 313/1050
# Number of sweeps: 300
# 50119001_ANT_Pc.avg 314/1050
# Number of sweeps: 300
# 50119001_ANT_Wc.avg 315/1050
# Number of sweeps: 300
# 50120001_ANT_Ac.avg 316/1050
# Number of sweeps: 300
# 50120001_ANT_Jc.avg 317/1050
# Number of sweeps: 300
# 50120001_ANT_Pc.avg 318/1050
# Number of sweeps: 300
# 50120001_ANT_Wc.avg 319/1050
# Number of sweeps: 300
# 50121007_ANT_Ac.avg 320/1050
# Number of sweeps: 300
# 50121007_ANT_Jc.avg 321/1050
# Number of sweeps: 300
# 50121007_ANT_Pc.avg 322/1050
# Number of sweeps: 300
# 50121007_ANT_Wc.avg 323/1050
# Number of sweeps: 300
# 50121014_ANT_Ac.avg 324/1050
# Number of sweeps: 300
# 50121014_ANT_Jc.avg 325/1050
# Number of sweeps: 300
# 50121014_ANT_Pc.avg 326/1050
# Number of sweeps: 300
# 50121014_ANT_Wc.avg 327/1050
# Number of sweeps: 300
# 50124004_ANT_Ac.avg 328/1050
# Number of sweeps: 300
# 50124004_ANT_Jc.avg 329/1050
# Number of sweeps: 300
# 50124004_ANT_Pc.avg 330/1050
# Number of sweeps: 300
# 50124004_ANT_Wc.avg 331/1050
# Number of sweeps: 300
# 50126014_ANT_Ac.avg 332/1050
# Number of sweeps: 300
# 50126014_ANT_Jc.avg 333/1050
# Number of sweeps: 300
# 50126014_ANT_Pc.avg 334/1050
# Number of sweeps: 300
# 50126014_ANT_Wc.avg 335/1050
# Number of sweeps: 300
# 50126018_ANT_Ac.avg 336/1050
# Number of sweeps: 300
# 50126018_ANT_Jc.avg 337/1050
# Number of sweeps: 300
# 50126018_ANT_Pc.avg 338/1050
# Number of sweeps: 300
# 50126018_ANT_Wc.avg 339/1050
# Number of sweeps: 300
# 50126019_ANT_Ac.avg 340/1050
# Number of sweeps: 300
# 50126019_ANT_Jc.avg 341/1050
# Number of sweeps: 300
# 50126019_ANT_Pc.avg 342/1050
# Number of sweeps: 300
# 50126019_ANT_Wc.avg 343/1050
# Number of sweeps: 300
# 50126133_ANT_Ac.avg 344/1050
# Number of sweeps: 300
# 50126133_ANT_Jc.avg 345/1050
# Number of sweeps: 300
# 50126133_ANT_Pc.avg 346/1050
# Number of sweeps: 300
# 50126133_ANT_Wc.avg 347/1050
# Number of sweeps: 300
# 50126134_ANT_Ac.avg 348/1050
# Number of sweeps: 300
# 50126134_ANT_Jc.avg 349/1050
# Number of sweeps: 300
# 50126134_ANT_Pc.avg 350/1050
# Number of sweeps: 300
# 50126134_ANT_Wc.avg 351/1050
# Number of sweeps: 300
# 50126140_ANT_Ac.avg 352/1050
# Number of sweeps: 300
# 50126140_ANT_Jc.avg 353/1050
# Number of sweeps: 300
# 50126140_ANT_Pc.avg 354/1050
# Number of sweeps: 300
# 50126140_ANT_Wc.avg 355/1050
# Number of sweeps: 300
# 50127022_ANT_Ac.avg 356/1050
# Number of sweeps: 300
# 50127022_ANT_Jc.avg 357/1050
# Number of sweeps: 300
# 50127022_ANT_Pc.avg 358/1050
# Number of sweeps: 300
# 50127022_ANT_Wc.avg 359/1050
# Number of sweeps: 300
# 50134006_ANT_Ac.avg 360/1050
# Number of sweeps: 300
# 50134006_ANT_Jc.avg 361/1050
# Number of sweeps: 300
# 50134006_ANT_Pc.avg 362/1050
# Number of sweeps: 300
# 50134006_ANT_Wc.avg 363/1050
# Number of sweeps: 300
# 50134009_ANT_Ac.avg 364/1050
# Number of sweeps: 300
# 50134009_ANT_Jc.avg 365/1050
# Number of sweeps: 300
# 50134009_ANT_Pc.avg 366/1050
# Number of sweeps: 300
# 50134009_ANT_Wc.avg 367/1050
# Number of sweeps: 300
# 50134010_ANT_Ac.avg 368/1050
# Number of sweeps: 300
# 50134010_ANT_Jc.avg 369/1050
# Number of sweeps: 300
# 50134010_ANT_Pc.avg 370/1050
# Number of sweeps: 300
# 50134010_ANT_Wc.avg 371/1050
# Number of sweeps: 300
# 50134011_ANT_Ac.avg 372/1050
# Number of sweeps: 300
# 50134011_ANT_Jc.avg 373/1050
# Number of sweeps: 300
# 50134011_ANT_Pc.avg 374/1050
# Number of sweeps: 300
# 50134011_ANT_Wc.avg 375/1050
# Number of sweeps: 300
# 50134050_ANT_Ac.avg 376/1050
# Number of sweeps: 300
# 50134050_ANT_Jc.avg 377/1050
# Number of sweeps: 300
# 50134050_ANT_Pc.avg 378/1050
# Number of sweeps: 300
# 50134050_ANT_Wc.avg 379/1050
# Number of sweeps: 300
# 50135001_ANT_Ac.avg 380/1050
# Number of sweeps: 300
# 50135001_ANT_Jc.avg 381/1050
# Number of sweeps: 300
# 50135001_ANT_Pc.avg 382/1050
# Number of sweeps: 300
# 50135001_ANT_Wc.avg 383/1050
# Number of sweeps: 300
# 50135004_ANT_Ac.avg 384/1050
# Number of sweeps: 300
# 50135004_ANT_Jc.avg 385/1050
# Number of sweeps: 300
# 50135004_ANT_Pc.avg 386/1050
# Number of sweeps: 300
# 50135004_ANT_Wc.avg 387/1050
# Number of sweeps: 300
# 50135005_ANT_Ac.avg 388/1050
# Number of sweeps: 300
# 50135005_ANT_Jc.avg 389/1050
# Number of sweeps: 300
# 50135005_ANT_Pc.avg 390/1050
# Number of sweeps: 300
# 50135005_ANT_Wc.avg 391/1050
# Number of sweeps: 300
# 50135110_ANT_Ac.avg 392/1050
# Number of sweeps: 300
# 50135110_ANT_Jc.avg 393/1050
# Number of sweeps: 300
# 50135110_ANT_Pc.avg 394/1050
# Number of sweeps: 300
# 50135110_ANT_Wc.avg 395/1050
# Number of sweeps: 300
# 50136003_ANT_Ac.avg 396/1050
# Number of sweeps: 300
# 50136003_ANT_Jc.avg 397/1050
# Number of sweeps: 300
# 50136003_ANT_Pc.avg 398/1050
# Number of sweeps: 300
# 50136003_ANT_Wc.avg 399/1050
# Number of sweeps: 300
# 50136006_ANT_Ac.avg 400/1050
# Number of sweeps: 300
# 50136006_ANT_Jc.avg 401/1050
# Number of sweeps: 300
# 50136006_ANT_Pc.avg 402/1050
# Number of sweeps: 300
# 50136006_ANT_Wc.avg 403/1050
# Number of sweeps: 300
# 50137001_ANT_Ac.avg 404/1050
# Number of sweeps: 300
# 50137001_ANT_Jc.avg 405/1050
# Number of sweeps: 300
# 50137001_ANT_Pc.avg 406/1050
# Number of sweeps: 300
# 50137001_ANT_Wc.avg 407/1050
# Number of sweeps: 300
# 50137002_ANT_Ac.avg 408/1050
# Number of sweeps: 300
# 50137002_ANT_Jc.avg 409/1050
# Number of sweeps: 300
# 50137002_ANT_Pc.avg 410/1050
# Number of sweeps: 300
# 50137002_ANT_Wc.avg 411/1050
# Number of sweeps: 300
# 50137007_ANT_Ac.avg 412/1050
# Number of sweeps: 300
# 50137007_ANT_Jc.avg 413/1050
# Number of sweeps: 300
# 50137007_ANT_Pc.avg 414/1050
# Number of sweeps: 300
# 50137007_ANT_Wc.avg 415/1050
# Number of sweeps: 300
# 50137008_ANT_Ac.avg 416/1050
# Number of sweeps: 300
# 50137008_ANT_Jc.avg 417/1050
# Number of sweeps: 300
# 50137008_ANT_Pc.avg 418/1050
# Number of sweeps: 300
# 50137008_ANT_Wc.avg 419/1050
# Number of sweeps: 300
# 50138023_ANT_Ac.avg 420/1050
# Number of sweeps: 300
# 50138023_ANT_Jc.avg 421/1050
# Number of sweeps: 300
# 50138023_ANT_Pc.avg 422/1050
# Number of sweeps: 300
# 50138023_ANT_Wc.avg 423/1050
# Number of sweeps: 300
# 50138024_ANT_Ac.avg 424/1050
# Number of sweeps: 300
# 50138024_ANT_Jc.avg 425/1050
# Number of sweeps: 300
# 50138024_ANT_Pc.avg 426/1050
# Number of sweeps: 300
# 50138024_ANT_Wc.avg 427/1050
# Number of sweeps: 300
# 50138025_ANT_Ac.avg 428/1050
# Number of sweeps: 300
# 50138025_ANT_Jc.avg 429/1050
# Number of sweeps: 300
# 50138025_ANT_Pc.avg 430/1050
# Number of sweeps: 300
# 50138025_ANT_Wc.avg 431/1050
# Number of sweeps: 300
# 50138026_ANT_Ac.avg 432/1050
# Number of sweeps: 300
# 50138026_ANT_Jc.avg 433/1050
# Number of sweeps: 300
# 50138026_ANT_Pc.avg 434/1050
# Number of sweeps: 300
# 50138026_ANT_Wc.avg 435/1050
# Number of sweeps: 300
# 50138128_ANT_Ac.avg 436/1050
# Number of sweeps: 300
# 50138128_ANT_Jc.avg 437/1050
# Number of sweeps: 300
# 50138128_ANT_Pc.avg 438/1050
# Number of sweeps: 300
# 50138128_ANT_Wc.avg 439/1050
# Number of sweeps: 300
# 50138130_ANT_Ac.avg 440/1050
# Number of sweeps: 300
# 50138130_ANT_Jc.avg 441/1050
# Number of sweeps: 300
# 50138130_ANT_Pc.avg 442/1050
# Number of sweeps: 300
# 50138130_ANT_Wc.avg 443/1050
# Number of sweeps: 300
# 50138131_ANT_Ac.avg 444/1050
# Number of sweeps: 300
# 50138131_ANT_Jc.avg 445/1050
# Number of sweeps: 300
# 50138131_ANT_Pc.avg 446/1050
# Number of sweeps: 300
# 50138131_ANT_Wc.avg 447/1050
# Number of sweeps: 300
# 50138132_ANT_Ac.avg 448/1050
# Number of sweeps: 300
# 50138132_ANT_Jc.avg 449/1050
# Number of sweeps: 300
# 50138132_ANT_Pc.avg 450/1050
# Number of sweeps: 300
# 50138132_ANT_Wc.avg 451/1050
# Number of sweeps: 300
# 50138300_ANT_Ac.avg 452/1050
# Number of sweeps: 300
# 50138300_ANT_Jc.avg 453/1050
# Number of sweeps: 300
# 50138300_ANT_Pc.avg 454/1050
# Number of sweeps: 300
# 50138300_ANT_Wc.avg 455/1050
# Number of sweeps: 300
# 50141009_ANT_Ac.avg 456/1050
# Number of sweeps: 300
# 50141009_ANT_Jc.avg 457/1050
# Number of sweeps: 300
# 50141009_ANT_Pc.avg 458/1050
# Number of sweeps: 300
# 50141009_ANT_Wc.avg 459/1050
# Number of sweeps: 300
# 50141010_ANT_Ac.avg 460/1050
# Number of sweeps: 300
# 50141010_ANT_Jc.avg 461/1050
# Number of sweeps: 300
# 50141010_ANT_Pc.avg 462/1050
# Number of sweeps: 300
# 50141010_ANT_Wc.avg 463/1050
# Number of sweeps: 300
# 50141025_ANT_Ac.avg 464/1050
# Number of sweeps: 300
# 50141025_ANT_Jc.avg 465/1050
# Number of sweeps: 300
# 50141025_ANT_Pc.avg 466/1050
# Number of sweeps: 300
# 50141025_ANT_Wc.avg 467/1050
# Number of sweeps: 300
# 50144022_ANT_Ac.avg 468/1050
# Number of sweeps: 300
# 50144022_ANT_Jc.avg 469/1050
# Number of sweeps: 300
# 50144022_ANT_Pc.avg 470/1050
# Number of sweeps: 300
# 50144022_ANT_Wc.avg 471/1050
# Number of sweeps: 300
# 50144023_ANT_Ac.avg 472/1050
# Number of sweeps: 300
# 50144023_ANT_Jc.avg 473/1050
# Number of sweeps: 300
# 50144023_ANT_Pc.avg 474/1050
# Number of sweeps: 300
# 50144023_ANT_Wc.avg 475/1050
# Number of sweeps: 300
# 50144030_ANT_Ac.avg 476/1050
# Number of sweeps: 300
# 50144030_ANT_Jc.avg 477/1050
# Number of sweeps: 300
# 50144030_ANT_Pc.avg 478/1050
# Number of sweeps: 300
# 50144030_ANT_Wc.avg 479/1050
# Number of sweeps: 300
# 50147004_ANT_Ac.avg 480/1050
# Number of sweeps: 300
# 50147004_ANT_Jc.avg 481/1050
# Number of sweeps: 300
# 50147004_ANT_Pc.avg 482/1050
# Number of sweeps: 300
# 50147004_ANT_Wc.avg 483/1050
# Number of sweeps: 300
# 50147015_ANT_Ac.avg 484/1050
# Number of sweeps: 300
# 50147015_ANT_Jc.avg 485/1050
# Number of sweeps: 300
# 50147015_ANT_Pc.avg 486/1050
# Number of sweeps: 300
# 50147015_ANT_Wc.avg 487/1050
# Number of sweeps: 300
# 50147016_ANT_Ac.avg 488/1050
# Number of sweeps: 300
# 50147016_ANT_Jc.avg 489/1050
# Number of sweeps: 300
# 50147016_ANT_Pc.avg 490/1050
# Number of sweeps: 300
# 50147016_ANT_Wc.avg 491/1050
# Number of sweeps: 300
# 50147064_ANT_Ac.avg 492/1050
# Number of sweeps: 300
# 50147064_ANT_Jc.avg 493/1050
# Number of sweeps: 300
# 50147064_ANT_Pc.avg 494/1050
# Number of sweeps: 300
# 50147064_ANT_Wc.avg 495/1050
# Number of sweeps: 300
# 50151002_ANT_Ac.avg 496/1050
# Number of sweeps: 300
# 50151002_ANT_Jc.avg 497/1050
# Number of sweeps: 300
# 50151002_ANT_Pc.avg 498/1050
# Number of sweeps: 300
# 50151002_ANT_Wc.avg 499/1050
# Number of sweeps: 300
# 50154001_ANT_Ac.avg 500/1050
# Number of sweeps: 300
# 50154001_ANT_Jc.avg 501/1050
# Number of sweeps: 300
# 50154001_ANT_Pc.avg 502/1050
# Number of sweeps: 300
# 50154001_ANT_Wc.avg 503/1050
# Number of sweeps: 300
# 50155007_ANT_Ac.avg 504/1050
# Number of sweeps: 300
# 50155007_ANT_Jc.avg 505/1050
# Number of sweeps: 300
# 50155007_ANT_Pc.avg 506/1050
# Number of sweeps: 300
# 50155007_ANT_Wc.avg 507/1050
# Number of sweeps: 300
# 50157010_ANT_Ac.avg 508/1050
# Number of sweeps: 300
# 50157010_ANT_Jc.avg 509/1050
# Number of sweeps: 300
# 50157010_ANT_Pc.avg 510/1050
# Number of sweeps: 300
# 50157010_ANT_Wc.avg 511/1050
# Number of sweeps: 300
# 50157044_ANT_Ac.avg 512/1050
# Number of sweeps: 300
# 50157044_ANT_Jc.avg 513/1050
# Number of sweeps: 300
# 50157044_ANT_Pc.avg 514/1050
# Number of sweeps: 300
# 50157044_ANT_Wc.avg 515/1050
# Number of sweeps: 300
# 50158002_ANT_Ac.avg 516/1050
# Number of sweeps: 300
# 50158002_ANT_Jc.avg 517/1050
# Number of sweeps: 300
# 50158002_ANT_Pc.avg 518/1050
# Number of sweeps: 300
# 50158002_ANT_Wc.avg 519/1050
# Number of sweeps: 300
# 50159002_ANT_Ac.avg 520/1050
# Number of sweeps: 300
# 50159002_ANT_Jc.avg 521/1050
# Number of sweeps: 300
# 50159002_ANT_Pc.avg 522/1050
# Number of sweeps: 300
# 50159002_ANT_Wc.avg 523/1050
# Number of sweeps: 300
# 50160003_ANT_Ac.avg 524/1050
# Number of sweeps: 300
# 50160003_ANT_Jc.avg 525/1050
# Number of sweeps: 300
# 50160003_ANT_Pc.avg 526/1050
# Number of sweeps: 300
# 50160003_ANT_Wc.avg 527/1050
# Number of sweeps: 300
# 50160007_ANT_Ac.avg 528/1050
# Number of sweeps: 300
# 50160007_ANT_Jc.avg 529/1050
# Number of sweeps: 300
# 50160007_ANT_Pc.avg 530/1050
# Number of sweeps: 300
# 50160007_ANT_Wc.avg 531/1050
# Number of sweeps: 300
# 50160010_ANT_Ac.avg 532/1050
# Number of sweeps: 300
# 50160010_ANT_Jc.avg 533/1050
# Number of sweeps: 300
# 50160010_ANT_Pc.avg 534/1050
# Number of sweeps: 300
# 50160010_ANT_Wc.avg 535/1050
# Number of sweeps: 300
# 50160011_ANT_Ac.avg 536/1050
# Number of sweeps: 300
# 50160011_ANT_Jc.avg 537/1050
# Number of sweeps: 300
# 50160011_ANT_Pc.avg 538/1050
# Number of sweeps: 300
# 50160011_ANT_Wc.avg 539/1050
# Number of sweeps: 300
# 50162007_ANT_Ac.avg 540/1050
# Number of sweeps: 300
# 50162007_ANT_Jc.avg 541/1050
# Number of sweeps: 300
# 50162007_ANT_Pc.avg 542/1050
# Number of sweeps: 300
# 50162007_ANT_Wc.avg 543/1050
# Number of sweeps: 300
# 50163005_ANT_Ac.avg 544/1050
# Number of sweeps: 300
# 50163005_ANT_Jc.avg 545/1050
# Number of sweeps: 300
# 50163005_ANT_Pc.avg 546/1050
# Number of sweeps: 300
# 50163005_ANT_Wc.avg 547/1050
# Number of sweeps: 300
# 50163010_ANT_Ac.avg 548/1050
# Number of sweeps: 300
# 50163010_ANT_Jc.avg 549/1050
# Number of sweeps: 300
# 50163010_ANT_Pc.avg 550/1050
# Number of sweeps: 300
# 50163010_ANT_Wc.avg 551/1050
# Number of sweeps: 300
# 50165001_ANT_Ac.avg 552/1050
# Number of sweeps: 300
# 50165001_ANT_Jc.avg 553/1050
# Number of sweeps: 300
# 50165001_ANT_Pc.avg 554/1050
# Number of sweeps: 300
# 50165001_ANT_Wc.avg 555/1050
# Number of sweeps: 300
# 50168008_ANT_Ac.avg 556/1050
# Number of sweeps: 300
# 50168008_ANT_Jc.avg 557/1050
# Number of sweeps: 300
# 50168008_ANT_Pc.avg 558/1050
# Number of sweeps: 300
# 50168008_ANT_Wc.avg 559/1050
# Number of sweeps: 300
# 50168009_ANT_Ac.avg 560/1050
# Number of sweeps: 300
# 50168009_ANT_Jc.avg 561/1050
# Number of sweeps: 300
# 50168009_ANT_Pc.avg 562/1050
# Number of sweeps: 300
# 50168009_ANT_Wc.avg 563/1050
# Number of sweeps: 300
# 50169008_ANT_Ac.avg 564/1050
# Number of sweeps: 300
# 50169008_ANT_Jc.avg 565/1050
# Number of sweeps: 300
# 50169008_ANT_Pc.avg 566/1050
# Number of sweeps: 300
# 50169008_ANT_Wc.avg 567/1050
# Number of sweeps: 300
# 50169321_ANT_Ac.avg 568/1050
# Number of sweeps: 300
# 50169321_ANT_Jc.avg 569/1050
# Number of sweeps: 300
# 50169321_ANT_Pc.avg 570/1050
# Number of sweeps: 300
# 50169321_ANT_Wc.avg 571/1050
# Number of sweeps: 300
# 50170001_ANT_Ac.avg 572/1050
# Number of sweeps: 300
# 50170001_ANT_Jc.avg 573/1050
# Number of sweeps: 300
# 50170001_ANT_Pc.avg 574/1050
# Number of sweeps: 300
# 50170001_ANT_Wc.avg 575/1050
# Number of sweeps: 300
# 50173009_ANT_Ac.avg 576/1050
# Number of sweeps: 300
# 50173009_ANT_Jc.avg 577/1050
# Number of sweeps: 300
# 50173009_ANT_Pc.avg 578/1050
# Number of sweeps: 300
# 50173009_ANT_Wc.avg 579/1050
# Number of sweeps: 300
# 50174028_ANT_Ac.avg 580/1050
# Number of sweeps: 300
# 50174028_ANT_Jc.avg 581/1050
# Number of sweeps: 300
# 50174028_ANT_Pc.avg 582/1050
# Number of sweeps: 300
# 50174028_ANT_Wc.avg 583/1050
# Number of sweeps: 300
# 50175003_ANT_Ac.avg 584/1050
# Number of sweeps: 300
# 50175003_ANT_Jc.avg 585/1050
# Number of sweeps: 300
# 50175003_ANT_Pc.avg 586/1050
# Number of sweeps: 300
# 50175003_ANT_Wc.avg 587/1050
# Number of sweeps: 300
# 50175006_ANT_Ac.avg 588/1050
# Number of sweeps: 300
# 50175006_ANT_Jc.avg 589/1050
# Number of sweeps: 300
# 50175006_ANT_Pc.avg 590/1050
# Number of sweeps: 300
# 50175006_ANT_Wc.avg 591/1050
# Number of sweeps: 300
# 50175007_ANT_Ac.avg 592/1050
# Number of sweeps: 300
# 50175007_ANT_Jc.avg 593/1050
# Number of sweeps: 300
# 50175007_ANT_Pc.avg 594/1050
# Number of sweeps: 300
# 50175007_ANT_Wc.avg 595/1050
# Number of sweeps: 300
# 50177001_ANT_Ac.avg 596/1050
# Number of sweeps: 300
# 50177001_ANT_Jc.avg 597/1050
# Number of sweeps: 300
# 50177001_ANT_Pc.avg 598/1050
# Number of sweeps: 300
# 50177001_ANT_Wc.avg 599/1050
# Number of sweeps: 300
# 50177002_ANT_Ac.avg 600/1050
# Number of sweeps: 300
# 50177002_ANT_Jc.avg 601/1050
# Number of sweeps: 300
# 50177002_ANT_Pc.avg 602/1050
# Number of sweeps: 300
# 50177002_ANT_Wc.avg 603/1050
# Number of sweeps: 300
# 50178011_ANT_Ac.avg 604/1050
# Number of sweeps: 300
# 50178011_ANT_Jc.avg 605/1050
# Number of sweeps: 300
# 50178011_ANT_Pc.avg 606/1050
# Number of sweeps: 300
# 50178011_ANT_Wc.avg 607/1050
# Number of sweeps: 300
# 50179003_ANT_Ac.avg 608/1050
# Number of sweeps: 300
# 50179003_ANT_Jc.avg 609/1050
# Number of sweeps: 300
# 50179003_ANT_Pc.avg 610/1050
# Number of sweeps: 300
# 50179003_ANT_Wc.avg 611/1050
# Number of sweeps: 300
# 50179010_ANT_Ac.avg 612/1050
# Number of sweeps: 300
# 50179010_ANT_Jc.avg 613/1050
# Number of sweeps: 300
# 50179010_ANT_Pc.avg 614/1050
# Number of sweeps: 300
# 50179010_ANT_Wc.avg 615/1050
# Number of sweeps: 300
# 50179013_ANT_Ac.avg 616/1050
# Number of sweeps: 300
# 50179013_ANT_Jc.avg 617/1050
# Number of sweeps: 300
# 50179013_ANT_Pc.avg 618/1050
# Number of sweeps: 300
# 50179013_ANT_Wc.avg 619/1050
# Number of sweeps: 300
# 50180011_ANT_Ac.avg 620/1050
# Number of sweeps: 300
# 50180011_ANT_Jc.avg 621/1050
# Number of sweeps: 300
# 50180011_ANT_Pc.avg 622/1050
# Number of sweeps: 300
# 50180011_ANT_Wc.avg 623/1050
# Number of sweeps: 300
# 50180014_ANT_Ac.avg 624/1050
# Number of sweeps: 300
# 50180014_ANT_Jc.avg 625/1050
# Number of sweeps: 300
# 50180014_ANT_Pc.avg 626/1050
# Number of sweeps: 300
# 50180014_ANT_Wc.avg 627/1050
# Number of sweeps: 300
# 50180016_ANT_Ac.avg 628/1050
# Number of sweeps: 300
# 50180016_ANT_Jc.avg 629/1050
# Number of sweeps: 300
# 50180016_ANT_Pc.avg 630/1050
# Number of sweeps: 300
# 50180016_ANT_Wc.avg 631/1050
# Number of sweeps: 300
# 50180023_ANT_Ac.avg 632/1050
# Number of sweeps: 300
# 50180023_ANT_Jc.avg 633/1050
# Number of sweeps: 300
# 50180023_ANT_Pc.avg 634/1050
# Number of sweeps: 300
# 50180023_ANT_Wc.avg 635/1050
# Number of sweeps: 300
# 50180108_ANT_Ac.avg 636/1050
# Number of sweeps: 300
# 50180108_ANT_Jc.avg 637/1050
# Number of sweeps: 300
# 50180108_ANT_Pc.avg 638/1050
# Number of sweeps: 300
# 50180108_ANT_Wc.avg 639/1050
# Number of sweeps: 300
# 50184001_ANT_Ac.avg 640/1050
# Number of sweeps: 300
# 50184001_ANT_Jc.avg 641/1050
# Number of sweeps: 300
# 50184001_ANT_Pc.avg 642/1050
# Number of sweeps: 300
# 50184001_ANT_Wc.avg 643/1050
# Number of sweeps: 300
# 50184008_ANT_Ac.avg 644/1050
# Number of sweeps: 300
# 50184008_ANT_Jc.avg 645/1050
# Number of sweeps: 300
# 50184008_ANT_Pc.avg 646/1050
# Number of sweeps: 300
# 50184008_ANT_Wc.avg 647/1050
# Number of sweeps: 300
# 50184035_ANT_Ac.avg 648/1050
# Number of sweeps: 300
# 50184035_ANT_Jc.avg 649/1050
# Number of sweeps: 300
# 50184035_ANT_Pc.avg 650/1050
# Number of sweeps: 300
# 50184035_ANT_Wc.avg 651/1050
# Number of sweeps: 300
# 50186001_ANT_Ac.avg 652/1050
# Number of sweeps: 300
# 50186001_ANT_Jc.avg 653/1050
# Number of sweeps: 300
# 50186001_ANT_Pc.avg 654/1050
# Number of sweeps: 300
# 50186001_ANT_Wc.avg 655/1050
# Number of sweeps: 300
# 50186006_ANT_Ac.avg 656/1050
# Number of sweeps: 300
# 50186006_ANT_Jc.avg 657/1050
# Number of sweeps: 300
# 50186006_ANT_Pc.avg 658/1050
# Number of sweeps: 300
# 50186006_ANT_Wc.avg 659/1050
# Number of sweeps: 300
# 50186046_ANT_Ac.avg 660/1050
# Number of sweeps: 300
# 50186046_ANT_Jc.avg 661/1050
# Number of sweeps: 300
# 50186046_ANT_Pc.avg 662/1050
# Number of sweeps: 300
# 50186046_ANT_Wc.avg 663/1050
# Number of sweeps: 300
# 50189022_ANT_Ac.avg 664/1050
# Number of sweeps: 300
# 50189022_ANT_Jc.avg 665/1050
# Number of sweeps: 300
# 50189022_ANT_Pc.avg 666/1050
# Number of sweeps: 300
# 50189022_ANT_Wc.avg 667/1050
# Number of sweeps: 300
# 50190138_ANT_Ac.avg 668/1050
# Number of sweeps: 300
# 50190138_ANT_Jc.avg 669/1050
# Number of sweeps: 300
# 50190138_ANT_Pc.avg 670/1050
# Number of sweeps: 300
# 50190138_ANT_Wc.avg 671/1050
# Number of sweeps: 300
# 50190140_ANT_Ac.avg 672/1050
# Number of sweeps: 300
# 50190140_ANT_Jc.avg 673/1050
# Number of sweeps: 300
# 50190140_ANT_Pc.avg 674/1050
# Number of sweeps: 300
# 50190140_ANT_Wc.avg 675/1050
# Number of sweeps: 300
# 50190219_ANT_Ac.avg 676/1050
# Number of sweeps: 300
# 50190219_ANT_Jc.avg 677/1050
# Number of sweeps: 300
# 50190219_ANT_Pc.avg 678/1050
# Number of sweeps: 300
# 50190219_ANT_Wc.avg 679/1050
# Number of sweeps: 300
# 50193018_ANT_Ac.avg 680/1050
# Number of sweeps: 300
# 50193018_ANT_Jc.avg 681/1050
# Number of sweeps: 300
# 50193018_ANT_Pc.avg 682/1050
# Number of sweeps: 300
# 50193018_ANT_Wc.avg 683/1050
# Number of sweeps: 300
# 50193019_ANT_Ac.avg 684/1050
# Number of sweeps: 300
# 50193019_ANT_Jc.avg 685/1050
# Number of sweeps: 300
# 50193019_ANT_Pc.avg 686/1050
# Number of sweeps: 300
# 50193019_ANT_Wc.avg 687/1050
# Number of sweeps: 300
# 50195009_ANT_Ac.avg 688/1050
# Number of sweeps: 300
# 50195009_ANT_Jc.avg 689/1050
# Number of sweeps: 300
# 50195009_ANT_Pc.avg 690/1050
# Number of sweeps: 300
# 50195009_ANT_Wc.avg 691/1050
# Number of sweeps: 300
# 50197003_ANT_Ac.avg 692/1050
# Number of sweeps: 300
# 50197003_ANT_Jc.avg 693/1050
# Number of sweeps: 300
# 50197003_ANT_Pc.avg 694/1050
# Number of sweeps: 300
# 50197003_ANT_Wc.avg 695/1050
# Number of sweeps: 300
# 50201002_ANT_Ac.avg 696/1050
# Number of sweeps: 300
# 50201002_ANT_Jc.avg 697/1050
# Number of sweeps: 300
# 50201002_ANT_Pc.avg 698/1050
# Number of sweeps: 300
# 50201002_ANT_Wc.avg 699/1050
# Number of sweeps: 300
# 50201003_ANT_Ac.avg 700/1050
# Number of sweeps: 300
# 50201003_ANT_Jc.avg 701/1050
# Number of sweeps: 300
# 50201003_ANT_Pc.avg 702/1050
# Number of sweeps: 300
# 50201003_ANT_Wc.avg 703/1050
# Number of sweeps: 300
# 50301027_ANT_Ac.avg 704/1050
# Number of sweeps: 300
# 50301027_ANT_Jc.avg 705/1050
# Number of sweeps: 300
# 50301027_ANT_Pc.avg 706/1050
# Number of sweeps: 300
# 50301027_ANT_Wc.avg 707/1050
# Number of sweeps: 300
# 50306001_ANT_Ac.avg 708/1050
# Number of sweeps: 300
# 50306001_ANT_Jc.avg 709/1050
# Number of sweeps: 300
# 50306001_ANT_Pc.avg 710/1050
# Number of sweeps: 300
# 50306001_ANT_Wc.avg 711/1050
# Number of sweeps: 300
# 50306002_ANT_Ac.avg 712/1050
# Number of sweeps: 300
# 50306002_ANT_Jc.avg 713/1050
# Number of sweeps: 300
# 50306002_ANT_Pc.avg 714/1050
# Number of sweeps: 300
# 50306002_ANT_Wc.avg 715/1050
# Number of sweeps: 300
# 50306004_ANT_Ac.avg 716/1050
# Number of sweeps: 300
# 50306004_ANT_Jc.avg 717/1050
# Number of sweeps: 300
# 50306004_ANT_Pc.avg 718/1050
# Number of sweeps: 300
# 50306004_ANT_Wc.avg 719/1050
# Number of sweeps: 300
# 50307001_ANT_Ac.avg 720/1050
# Number of sweeps: 300
# 50307001_ANT_Jc.avg 721/1050
# Number of sweeps: 300
# 50307001_ANT_Pc.avg 722/1050
# Number of sweeps: 300
# 50307001_ANT_Wc.avg 723/1050
# Number of sweeps: 300
# 50307012_ANT_Ac.avg 724/1050
# Number of sweeps: 300
# 50307012_ANT_Jc.avg 725/1050
# Number of sweeps: 300
# 50307012_ANT_Pc.avg 726/1050
# Number of sweeps: 300
# 50307012_ANT_Wc.avg 727/1050
# Number of sweeps: 300
# 50309001_ANT_Ac.avg 728/1050
# Number of sweeps: 300
# 50309001_ANT_Jc.avg 729/1050
# Number of sweeps: 300
# 50309001_ANT_Pc.avg 730/1050
# Number of sweeps: 300
# 50309001_ANT_Wc.avg 731/1050
# Number of sweeps: 300
# 50309012_ANT_Ac.avg 732/1050
# Number of sweeps: 300
# 50309012_ANT_Jc.avg 733/1050
# Number of sweeps: 300
# 50309012_ANT_Pc.avg 734/1050
# Number of sweeps: 300
# 50309012_ANT_Wc.avg 735/1050
# Number of sweeps: 300
# 50313192_ANT_Ac.avg 736/1050
# Number of sweeps: 300
# 50313192_ANT_Jc.avg 737/1050
# Number of sweeps: 300
# 50313192_ANT_Pc.avg 738/1050
# Number of sweeps: 300
# 50313192_ANT_Wc.avg 739/1050
# Number of sweeps: 300
# 50314001_ANT_Ac.avg 740/1050
# Number of sweeps: 300
# 50314001_ANT_Jc.avg 741/1050
# Number of sweeps: 300
# 50314001_ANT_Pc.avg 742/1050
# Number of sweeps: 300
# 50314001_ANT_Wc.avg 743/1050
# Number of sweeps: 300
# 50314002_ANT_Ac.avg 744/1050
# Number of sweeps: 300
# 50314002_ANT_Jc.avg 745/1050
# Number of sweeps: 300
# 50314002_ANT_Pc.avg 746/1050
# Number of sweeps: 300
# 50314002_ANT_Wc.avg 747/1050
# Number of sweeps: 300
# 50314003_ANT_Ac.avg 748/1050
# Number of sweeps: 300
# 50314003_ANT_Jc.avg 749/1050
# Number of sweeps: 300
# 50314003_ANT_Pc.avg 750/1050
# Number of sweeps: 300
# 50314003_ANT_Wc.avg 751/1050
# Number of sweeps: 300
# 50315001_ANT_Ac.avg 752/1050
# Number of sweeps: 300
# 50315001_ANT_Jc.avg 753/1050
# Number of sweeps: 300
# 50315001_ANT_Pc.avg 754/1050
# Number of sweeps: 300
# 50315001_ANT_Wc.avg 755/1050
# Number of sweeps: 300
# 50315002_ANT_Ac.avg 756/1050
# Number of sweeps: 300
# 50315002_ANT_Jc.avg 757/1050
# Number of sweeps: 300
# 50315002_ANT_Pc.avg 758/1050
# Number of sweeps: 300
# 50315002_ANT_Wc.avg 759/1050
# Number of sweeps: 300
# 50315007_ANT_Ac.avg 760/1050
# Number of sweeps: 300
# 50315007_ANT_Jc.avg 761/1050
# Number of sweeps: 300
# 50315007_ANT_Pc.avg 762/1050
# Number of sweeps: 300
# 50315007_ANT_Wc.avg 763/1050
# Number of sweeps: 300
# 50319001_ANT_Ac.avg 764/1050
# Number of sweeps: 300
# 50319001_ANT_Jc.avg 765/1050
# Number of sweeps: 300
# 50319001_ANT_Pc.avg 766/1050
# Number of sweeps: 300
# 50319001_ANT_Wc.avg 767/1050
# Number of sweeps: 300
# 50319014_ANT_Ac.avg 768/1050
# Number of sweeps: 300
# 50319014_ANT_Jc.avg 769/1050
# Number of sweeps: 300
# 50319014_ANT_Pc.avg 770/1050
# Number of sweeps: 300
# 50319014_ANT_Wc.avg 771/1050
# Number of sweeps: 300
# 50319015_ANT_Ac.avg 772/1050
# Number of sweeps: 300
# 50319015_ANT_Jc.avg 773/1050
# Number of sweeps: 300
# 50319015_ANT_Pc.avg 774/1050
# Number of sweeps: 300
# 50319015_ANT_Wc.avg 775/1050
# Number of sweeps: 300
# 50319023_ANT_Ac.avg 776/1050
# Number of sweeps: 300
# 50319023_ANT_Jc.avg 777/1050
# Number of sweeps: 300
# 50319023_ANT_Pc.avg 778/1050
# Number of sweeps: 300
# 50319023_ANT_Wc.avg 779/1050
# Number of sweeps: 300
# 50319025_ANT_Ac.avg 780/1050
# Number of sweeps: 300
# 50319025_ANT_Jc.avg 781/1050
# Number of sweeps: 300
# 50319025_ANT_Pc.avg 782/1050
# Number of sweeps: 300
# 50319025_ANT_Wc.avg 783/1050
# Number of sweeps: 300
# 50325001_ANT_Ac.avg 784/1050
# Number of sweeps: 300
# 50325001_ANT_Jc.avg 785/1050
# Number of sweeps: 300
# 50325001_ANT_Pc.avg 786/1050
# Number of sweeps: 300
# 50325001_ANT_Wc.avg 787/1050
# Number of sweeps: 300
# 50325015_ANT_Ac.avg 788/1050
# Number of sweeps: 300
# 50325015_ANT_Jc.avg 789/1050
# Number of sweeps: 300
# 50325015_ANT_Pc.avg 790/1050
# Number of sweeps: 300
# 50325015_ANT_Wc.avg 791/1050
# Number of sweeps: 300
# 50328002_ANT_Ac.avg 792/1050
# Number of sweeps: 300
# 50328002_ANT_Jc.avg 793/1050
# Number of sweeps: 300
# 50328002_ANT_Pc.avg 794/1050
# Number of sweeps: 300
# 50328002_ANT_Wc.avg 795/1050
# Number of sweeps: 300
# 50328003_ANT_Ac.avg 796/1050
# Number of sweeps: 300
# 50328003_ANT_Jc.avg 797/1050
# Number of sweeps: 300
# 50328003_ANT_Pc.avg 798/1050
# Number of sweeps: 300
# 50328003_ANT_Wc.avg 799/1050
# Number of sweeps: 300
# 50329029_ANT_Ac.avg 800/1050
# Number of sweeps: 300
# 50329029_ANT_Jc.avg 801/1050
# Number of sweeps: 300
# 50329029_ANT_Pc.avg 802/1050
# Number of sweeps: 300
# 50329029_ANT_Wc.avg 803/1050
# Number of sweeps: 300
# 50329034_ANT_Ac.avg 804/1050
# Number of sweeps: 300
# 50329034_ANT_Jc.avg 805/1050
# Number of sweeps: 300
# 50329034_ANT_Pc.avg 806/1050
# Number of sweeps: 300
# 50329034_ANT_Wc.avg 807/1050
# Number of sweeps: 300
# 50329037_ANT_Ac.avg 808/1050
# Number of sweeps: 300
# 50329037_ANT_Jc.avg 809/1050
# Number of sweeps: 300
# 50329037_ANT_Pc.avg 810/1050
# Number of sweeps: 300
# 50329037_ANT_Wc.avg 811/1050
# Number of sweeps: 300
# 50329038_ANT_Ac.avg 812/1050
# Number of sweeps: 300
# 50329038_ANT_Jc.avg 813/1050
# Number of sweeps: 300
# 50329038_ANT_Pc.avg 814/1050
# Number of sweeps: 300
# 50329038_ANT_Wc.avg 815/1050
# Number of sweeps: 300
# 50329039_ANT_Ac.avg 816/1050
# Number of sweeps: 300
# 50329039_ANT_Jc.avg 817/1050
# Number of sweeps: 300
# 50329039_ANT_Pc.avg 818/1050
# Number of sweeps: 300
# 50329039_ANT_Wc.avg 819/1050
# Number of sweeps: 300
# 50330004_ANT_Ac.avg 820/1050
# Number of sweeps: 300
# 50330004_ANT_Jc.avg 821/1050
# Number of sweeps: 300
# 50330004_ANT_Pc.avg 822/1050
# Number of sweeps: 300
# 50330004_ANT_Wc.avg 823/1050
# Number of sweeps: 300
# 50333004_ANT_Ac.avg 824/1050
# Number of sweeps: 300
# 50333004_ANT_Jc.avg 825/1050
# Number of sweeps: 300
# 50333004_ANT_Pc.avg 826/1050
# Number of sweeps: 300
# 50333004_ANT_Wc.avg 827/1050
# Number of sweeps: 300
# 50335046_ANT_Ac.avg 828/1050
# Number of sweeps: 300
# 50335046_ANT_Jc.avg 829/1050
# Number of sweeps: 300
# 50335046_ANT_Pc.avg 830/1050
# Number of sweeps: 300
# 50335046_ANT_Wc.avg 831/1050
# Number of sweeps: 300
# 50335047_ANT_Ac.avg 832/1050
# Number of sweeps: 300
# 50335047_ANT_Jc.avg 833/1050
# Number of sweeps: 300
# 50335047_ANT_Pc.avg 834/1050
# Number of sweeps: 300
# 50335047_ANT_Wc.avg 835/1050
# Number of sweeps: 300
# 50339001_ANT_Ac.avg 836/1050
# Number of sweeps: 300
# 50339001_ANT_Jc.avg 837/1050
# Number of sweeps: 300
# 50339001_ANT_Pc.avg 838/1050
# Number of sweeps: 300
# 50339001_ANT_Wc.avg 839/1050
# Number of sweeps: 300
# 50340002_ANT_Ac.avg 840/1050
# Error reading 50340002_ANT_Ac.avg: No accepted sweeps found.
# 50340002_ANT_Jc.avg 841/1050
# Error reading 50340002_ANT_Jc.avg: No accepted sweeps found.
# 50340002_ANT_Pc.avg 842/1050
# Error reading 50340002_ANT_Pc.avg: No accepted sweeps found.
# 50340002_ANT_Wc.avg 843/1050
# Error reading 50340002_ANT_Wc.avg: No accepted sweeps found.
# 50343001_ANT_Ac.avg 844/1050
# Number of sweeps: 300
# 50343001_ANT_Jc.avg 845/1050
# Number of sweeps: 300
# 50343001_ANT_Pc.avg 846/1050
# Number of sweeps: 300
# 50343001_ANT_Wc.avg 847/1050
# Number of sweeps: 300
# 50343014_ANT_Ac.avg 848/1050
# Number of sweeps: 300
# 50343014_ANT_Jc.avg 849/1050
# Number of sweeps: 300
# 50343014_ANT_Pc.avg 850/1050
# Number of sweeps: 300
# 50343014_ANT_Wc.avg 851/1050
# Number of sweeps: 300
# 50344002_ANT_Ac.avg 852/1050
# Number of sweeps: 300
# 50344002_ANT_Jc.avg 853/1050
# Number of sweeps: 300
# 50344002_ANT_Pc.avg 854/1050
# Number of sweeps: 300
# 50344002_ANT_Wc.avg 855/1050
# Number of sweeps: 300
# 50345001_ANT_Ac.avg 856/1050
# Number of sweeps: 300
# 50345001_ANT_Jc.avg 857/1050
# Number of sweeps: 300
# 50345001_ANT_Pc.avg 858/1050
# Number of sweeps: 300
# 50345001_ANT_Wc.avg 859/1050
# Number of sweeps: 300
# 50345002_ANT_Ac.avg 860/1050
# Number of sweeps: 300
# 50345002_ANT_Jc.avg 861/1050
# Number of sweeps: 300
# 50345002_ANT_Pc.avg 862/1050
# Number of sweeps: 300
# 50345002_ANT_Wc.avg 863/1050
# Number of sweeps: 300
# 50346001_ANT_Ac.avg 864/1050
# Number of sweeps: 300
# 50346001_ANT_Jc.avg 865/1050
# Number of sweeps: 300
# 50346001_ANT_Pc.avg 866/1050
# Number of sweeps: 300
# 50346001_ANT_Wc.avg 867/1050
# Number of sweeps: 300
# 50347001_ANT_Ac.avg 868/1050
# Number of sweeps: 300
# 50347001_ANT_Jc.avg 869/1050
# Number of sweeps: 300
# 50347001_ANT_Pc.avg 870/1050
# Number of sweeps: 300
# 50347001_ANT_Wc.avg 871/1050
# Number of sweeps: 300
# 50347003_ANT_Ac.avg 872/1050
# Number of sweeps: 300
# 50347003_ANT_Jc.avg 873/1050
# Number of sweeps: 300
# 50347003_ANT_Pc.avg 874/1050
# Number of sweeps: 300
# 50347003_ANT_Wc.avg 875/1050
# Number of sweeps: 300
# 50347006_ANT_Ac.avg 876/1050
# Number of sweeps: 300
# 50347006_ANT_Jc.avg 877/1050
# Number of sweeps: 300
# 50347006_ANT_Pc.avg 878/1050
# Number of sweeps: 300
# 50347006_ANT_Wc.avg 879/1050
# Number of sweeps: 300
# 50349018_ANT_Ac.avg 880/1050
# Number of sweeps: 300
# 50349018_ANT_Jc.avg 881/1050
# Number of sweeps: 300
# 50349018_ANT_Pc.avg 882/1050
# Number of sweeps: 300
# 50349018_ANT_Wc.avg 883/1050
# Number of sweeps: 300
# 50352007_ANT_Ac.avg 884/1050
# Number of sweeps: 300
# 50352007_ANT_Jc.avg 885/1050
# Number of sweeps: 300
# 50352007_ANT_Pc.avg 886/1050
# Number of sweeps: 300
# 50352007_ANT_Wc.avg 887/1050
# Number of sweeps: 300
# 50353001_ANT_Ac.avg 888/1050
# Number of sweeps: 300
# 50353001_ANT_Jc.avg 889/1050
# Number of sweeps: 300
# 50353001_ANT_Pc.avg 890/1050
# Number of sweeps: 300
# 50353001_ANT_Wc.avg 891/1050
# Number of sweeps: 300
# 50354003_ANT_Ac.avg 892/1050
# Number of sweeps: 300
# 50354003_ANT_Jc.avg 893/1050
# Number of sweeps: 300
# 50354003_ANT_Pc.avg 894/1050
# Number of sweeps: 300
# 50354003_ANT_Wc.avg 895/1050
# Number of sweeps: 300
# 50501001_ANT_Ac.avg 896/1050
# Number of sweeps: 300
# 50501001_ANT_Jc.avg 897/1050
# Number of sweeps: 300
# 50501001_ANT_Pc.avg 898/1050
# Number of sweeps: 300
# 50501001_ANT_Wc.avg 899/1050
# Number of sweeps: 300
# 50504001_ANT_Ac.avg 900/1050
# Number of sweeps: 300
# 50504001_ANT_Jc.avg 901/1050
# Number of sweeps: 300
# 50504001_ANT_Pc.avg 902/1050
# Number of sweeps: 300
# 50504001_ANT_Wc.avg 903/1050
# Number of sweeps: 300
# 50506001_ANT_Ac.avg 904/1050
# Number of sweeps: 300
# 50506001_ANT_Jc.avg 905/1050
# Number of sweeps: 300
# 50506001_ANT_Pc.avg 906/1050
# Number of sweeps: 300
# 50506001_ANT_Wc.avg 907/1050
# Number of sweeps: 300
# 50506003_ANT_Ac.avg 908/1050
# Number of sweeps: 300
# 50506003_ANT_Jc.avg 909/1050
# Number of sweeps: 300
# 50506003_ANT_Pc.avg 910/1050
# Number of sweeps: 300
# 50506003_ANT_Wc.avg 911/1050
# Number of sweeps: 300
# 50506006_ANT_Ac.avg 912/1050
# Number of sweeps: 300
# 50506006_ANT_Jc.avg 913/1050
# Number of sweeps: 300
# 50506006_ANT_Pc.avg 914/1050
# Number of sweeps: 300
# 50506006_ANT_Wc.avg 915/1050
# Number of sweeps: 300
# 50511001_ANT_Ac.avg 916/1050
# Number of sweeps: 300
# 50511001_ANT_Jc.avg 917/1050
# Number of sweeps: 300
# 50511001_ANT_Pc.avg 918/1050
# Number of sweeps: 300
# 50511001_ANT_Wc.avg 919/1050
# Number of sweeps: 300
# 50700004_ANT_Ac.avg 920/1050
# Number of sweeps: 300
# 50700004_ANT_Jc.avg 921/1050
# Number of sweeps: 300
# 50700004_ANT_Pc.avg 922/1050
# Number of sweeps: 300
# 50700004_ANT_Wc.avg 923/1050
# Number of sweeps: 300
# 50700031_ANT_Ac.avg 924/1050
# Number of sweeps: 300
# 50700031_ANT_Jc.avg 925/1050
# Number of sweeps: 300
# 50700031_ANT_Pc.avg 926/1050
# Number of sweeps: 300
# 50700031_ANT_Wc.avg 927/1050
# Number of sweeps: 300
# 50700034_ANT_Ac.avg 928/1050
# Number of sweeps: 300
# 50700034_ANT_Jc.avg 929/1050
# Number of sweeps: 300
# 50700034_ANT_Pc.avg 930/1050
# Number of sweeps: 300
# 50700034_ANT_Wc.avg 931/1050
# Number of sweeps: 300
# 50700054_ANT_Ac.avg 932/1050
# Number of sweeps: 300
# 50700054_ANT_Jc.avg 933/1050
# Number of sweeps: 300
# 50700054_ANT_Pc.avg 934/1050
# Number of sweeps: 300
# 50700054_ANT_Wc.avg 935/1050
# Number of sweeps: 300
# 50719007_ANT_Ac.avg 936/1050
# Number of sweeps: 300
# 50719007_ANT_Jc.avg 937/1050
# Number of sweeps: 300
# 50719007_ANT_Pc.avg 938/1050
# Number of sweeps: 300
# 50719007_ANT_Wc.avg 939/1050
# Number of sweeps: 300
# 50721001_ANT_Ac.avg 940/1050
# Number of sweeps: 300
# 50721001_ANT_Jc.avg 941/1050
# Number of sweeps: 300
# 50721001_ANT_Pc.avg 942/1050
# Number of sweeps: 300
# 50721001_ANT_Wc.avg 943/1050
# Number of sweeps: 300
# 50721003_ANT_Ac.avg 944/1050
# Number of sweeps: 300
# 50721003_ANT_Jc.avg 945/1050
# Number of sweeps: 300
# 50721003_ANT_Pc.avg 946/1050
# Number of sweeps: 300
# 50721003_ANT_Wc.avg 947/1050
# Number of sweeps: 300
# 50723002_ANT_Ac.avg 948/1050
# Number of sweeps: 300
# 50723002_ANT_Jc.avg 949/1050
# Number of sweeps: 300
# 50723002_ANT_Pc.avg 950/1050
# Number of sweeps: 300
# 50723002_ANT_Wc.avg 951/1050
# Error reading 50723002_ANT_Wc.avg: No accepted sweeps found.
# 50723005_ANT_Ac.avg 952/1050
# Number of sweeps: 300
# 50723005_ANT_Jc.avg 953/1050
# Number of sweeps: 300
# 50723005_ANT_Pc.avg 954/1050
# Number of sweeps: 300
# 50723005_ANT_Wc.avg 955/1050
# Number of sweeps: 300
# 50725001_ANT_Ac.avg 956/1050
# Number of sweeps: 300
# 50725001_ANT_Jc.avg 957/1050
# Number of sweeps: 300
# 50725001_ANT_Pc.avg 958/1050
# Number of sweeps: 300
# 50725001_ANT_Wc.avg 959/1050
# Number of sweeps: 300
# 50728001_ANT_Ac.avg 960/1050
# Number of sweeps: 300
# 50728001_ANT_Jc.avg 961/1050
# Number of sweeps: 300
# 50728001_ANT_Pc.avg 962/1050
# Number of sweeps: 300
# 50728001_ANT_Wc.avg 963/1050
# Number of sweeps: 300
# 50728002_ANT_Ac.avg 964/1050
# Number of sweeps: 300
# 50728002_ANT_Jc.avg 965/1050
# Number of sweeps: 300
# 50728002_ANT_Pc.avg 966/1050
# Number of sweeps: 300
# 50728002_ANT_Wc.avg 967/1050
# Number of sweeps: 300
# 50729001_ANT_Ac.avg 968/1050
# Number of sweeps: 300
# 50729001_ANT_Jc.avg 969/1050
# Number of sweeps: 300
# 50729001_ANT_Pc.avg 970/1050
# Number of sweeps: 300
# 50729001_ANT_Wc.avg 971/1050
# Number of sweeps: 300
# 50730002_ANT_Ac.avg 972/1050
# Number of sweeps: 300
# 50730002_ANT_Jc.avg 973/1050
# Number of sweeps: 300
# 50730002_ANT_Pc.avg 974/1050
# Number of sweeps: 300
# 50730002_ANT_Wc.avg 975/1050
# Number of sweeps: 300
# 50730004_ANT_Ac.avg 976/1050
# Number of sweeps: 300
# 50730004_ANT_Jc.avg 977/1050
# Number of sweeps: 300
# 50730004_ANT_Pc.avg 978/1050
# Number of sweeps: 300
# 50730004_ANT_Wc.avg 979/1050
# Number of sweeps: 300
# 50730005_ANT_Ac.avg 980/1050
# Number of sweeps: 300
# 50730005_ANT_Jc.avg 981/1050
# Number of sweeps: 300
# 50730005_ANT_Pc.avg 982/1050
# Number of sweeps: 300
# 50730005_ANT_Wc.avg 983/1050
# Number of sweeps: 300
# 50730015_ANT_Ac.avg 984/1050
# Number of sweeps: 300
# 50730015_ANT_Jc.avg 985/1050
# Number of sweeps: 300
# 50730015_ANT_Pc.avg 986/1050
# Number of sweeps: 300
# 50730015_ANT_Wc.avg 987/1050
# Number of sweeps: 300
# 50730020_ANT_Ac.avg 988/1050
# Number of sweeps: 300
# 50730020_ANT_Jc.avg 989/1050
# Number of sweeps: 300
# 50730020_ANT_Pc.avg 990/1050
# Number of sweeps: 300
# 50730020_ANT_Wc.avg 991/1050
# Number of sweeps: 300
# 50730022_ANT_Ac.avg 992/1050
# Number of sweeps: 300
# 50730022_ANT_Jc.avg 993/1050
# Number of sweeps: 300
# 50730022_ANT_Pc.avg 994/1050
# Number of sweeps: 300
# 50730022_ANT_Wc.avg 995/1050
# Number of sweeps: 300
# 50732001_ANT_Ac.avg 996/1050
# Number of sweeps: 300
# 50732001_ANT_Jc.avg 997/1050
# Number of sweeps: 300
# 50732001_ANT_Pc.avg 998/1050
# Number of sweeps: 300
# 50732001_ANT_Wc.avg 999/1050
# Number of sweeps: 300
# 50732007_ANT_Ac.avg 1000/1050
# Number of sweeps: 300
# 50732007_ANT_Jc.avg 1001/1050
# Number of sweeps: 300
# 50732007_ANT_Pc.avg 1002/1050
# Number of sweeps: 300
# 50732007_ANT_Wc.avg 1003/1050
# Number of sweeps: 300
# 50735002_ANT_Ac.avg 1004/1050
# Number of sweeps: 300
# 50735002_ANT_Jc.avg 1005/1050
# Number of sweeps: 300
# 50735002_ANT_Pc.avg 1006/1050
# Number of sweeps: 300
# 50735002_ANT_Wc.avg 1007/1050
# Number of sweeps: 300
# 50742001_ANT_Ac.avg 1008/1050
# Number of sweeps: 300
# 50742001_ANT_Jc.avg 1009/1050
# Number of sweeps: 300
# 50742001_ANT_Pc.avg 1010/1050
# Number of sweeps: 300
# 50742001_ANT_Wc.avg 1011/1050
# Number of sweeps: 300
# 50744001_ANT_Ac.avg 1012/1050
# Number of sweeps: 300
# 50744001_ANT_Jc.avg 1013/1050
# Number of sweeps: 300
# 50744001_ANT_Pc.avg 1014/1050
# Number of sweeps: 300
# 50744001_ANT_Wc.avg 1015/1050
# Number of sweeps: 300
# 50745001_ANT_Ac.avg 1016/1050
# Number of sweeps: 300
# 50745001_ANT_Jc.avg 1017/1050
# Number of sweeps: 300
# 50745001_ANT_Pc.avg 1018/1050
# Number of sweeps: 300
# 50745001_ANT_Wc.avg 1019/1050
# Number of sweeps: 300
# 50747001_ANT_Ac.avg 1020/1050
# Number of sweeps: 300
# 50747001_ANT_Jc.avg 1021/1050
# Number of sweeps: 300
# 50747001_ANT_Pc.avg 1022/1050
# Number of sweeps: 300
# 50747001_ANT_Wc.avg 1023/1050
# Number of sweeps: 300
# 50747003_ANT_Ac.avg 1024/1050
# Number of sweeps: 300
# 50747003_ANT_Jc.avg 1025/1050
# Number of sweeps: 300
# 50747003_ANT_Pc.avg 1026/1050
# Number of sweeps: 300
# 50747003_ANT_Wc.avg 1027/1050
# Number of sweeps: 300
# 50749001_ANT_Ac.avg 1028/1050
# Number of sweeps: 300
# 50749001_ANT_Jc.avg 1029/1050
# Number of sweeps: 300
# 50749001_ANT_Pc.avg 1030/1050
# Number of sweeps: 300
# 50749001_ANT_Wc.avg 1031/1050
# Number of sweeps: 300
# 50751002_ANT_Ac.avg 1032/1050
# Number of sweeps: 300
# 50751002_ANT_Jc.avg 1033/1050
# Number of sweeps: 300
# 50751002_ANT_Pc.avg 1034/1050
# Number of sweeps: 300
# 50751002_ANT_Wc.avg 1035/1050
# Number of sweeps: 300
# 50753013_ANT_Ac.avg 1036/1050
# Number of sweeps: 300
# 50753013_ANT_Jc.avg 1037/1050
# Number of sweeps: 300
# 50753013_ANT_Pc.avg 1038/1050
# Number of sweeps: 300
# 50753013_ANT_Wc.avg 1039/1050
# Number of sweeps: 300
# 50757001_ANT_Ac.avg 1040/1050
# Number of sweeps: 300
# 50757001_ANT_Jc.avg 1041/1050
# Number of sweeps: 300
# 50757001_ANT_Pc.avg 1042/1050
# Number of sweeps: 300
# 50757001_ANT_Wc.avg 1043/1050
# Number of sweeps: 300
# 50758001_ANT_Ac.avg 1044/1050
# Number of sweeps: 300
# 50758001_ANT_Jc.avg 1045/1050
# Number of sweeps: 300
# 50758001_ANT_Pc.avg 1046/1050
# Number of sweeps: 300
# 50758001_ANT_Wc.avg 1047/1050
# Number of sweeps: 300

# %%
subject_df
# Out:
#                      filename  time_ms      value channel
# 0         50001003_ANT_Ac.avg   -0.200  -0.787973     FP1
# 1         50001003_ANT_Ac.avg   -0.198  -0.729561     FP1
# 2         50001003_ANT_Ac.avg   -0.196  -0.634789     FP1
# 3         50001003_ANT_Ac.avg   -0.194  -0.512004     FP1
# 4         50001003_ANT_Ac.avg   -0.192  -0.364780     FP1
# ...                       ...      ...        ...     ...
# 33442747  50758001_ANT_Wc.avg    0.792  25.443733       Y
# 33442748  50758001_ANT_Wc.avg    0.794  24.913252       Y
# 33442749  50758001_ANT_Wc.avg    0.796  24.352968       Y
# 33442750  50758001_ANT_Wc.avg    0.798  23.759903       Y
# 33442751  50758001_ANT_Wc.avg    0.800  23.150444       Y
#
# [33442752 rows x 4 columns]

# %%
import datetime
now = datetime.datetime.now()
now = now.strftime("%Y-%m-%d_%H-%M")

subject_df.to_csv(
    '/home/woess/workspace/mnt/c/Users/woess/Desktop/ANT_coga_avg/coga_ant_avg_comb' + now + '.csv')

# %% [markdown]
# -----------------------------------------------TEST--------------------------------------------------------
